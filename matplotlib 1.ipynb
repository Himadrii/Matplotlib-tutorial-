# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,35,76,78,34,25,15]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color='pink')

# %%
plt.plot(x,y,color='pink',linewidth=5)

# %%
plt.plot(x,y,color='pink',linewidth=5,linestyle='dashdot')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='pink',linewidth=5,linestyle='dashdot')
