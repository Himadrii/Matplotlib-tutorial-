# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[12,23,34,56,67,78,98]

# %%
plt.plot(x,y,'r+')

# %%
plt.plot(x,y,'r+--')

# %%
plt.plot(x,y,'d')

# %%
plt.plot(x,y,color='red',marker='D',linestyle='')

# %%
plt.plot(x,y,color='red',alpha=0.5)
