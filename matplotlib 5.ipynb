# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
blood_sugar_men=[113,85,91,150,149,88,93,115,135,80,77,82,129]
blood_sugar_women=[120,98,87,145,134,143,120,99,142,67,100,149,150]
plt.hist([blood_sugar_men,blood_sugar_women],bins=[80,100,125,150],rwidth=0.95,color=['r','g'])
# Out:
# (array([[6., 2., 4.],
#         [3., 3., 6.]]),
#  array([ 80, 100, 125, 150]),
#  <a list of 2 Lists of Patches objects>)

# %%
blood_sugar_men=[113,85,91,150,149,88,93,115,135,80,77,82,129]
plt.hist(blood_sugar,bins=3)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <a list of 3 Patch objects>)

# %%
blood_sugar=[113,85,91,150,149,88,93,115,135,80,77,82,129]
plt.hist(blood_sugar,bins=3,rwidth=0.95)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <a list of 3 Patch objects>)

# %%
blood_sugar=[113,85,91,150,149,88,93,115,135,80,77,82,129]
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95)
# Out:
# (array([6., 2., 4.]), array([ 80, 100, 125, 150]), <a list of 3 Patch objects>)

# %%
blood_sugar=[113,85,91,150,149,88,93,115,135,80,77,82,129]
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,color='r')
# Out:
# (array([6., 2., 4.]), array([ 80, 100, 125, 150]), <a list of 3 Patch objects>)

# %%
blood_sugar=[113,85,91,150,149,88,93,115,135,80,77,82,129]
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,color='r',histtype='step')
# Out:
# (array([6., 2., 4.]), array([ 80, 100, 125, 150]), <a list of 1 Patch objects>)

# %%
blood_sugar_men=[113,85,91,150,149,88,93,115,135,80,77,82,129]
blood_sugar_women=[120,98,87,145,134,143,120,99,142,67,100,149,150]

plt.xlabel("sugar range")
plt.ylabel("number of patients")
plt.title("blood sugar chart")
plt.hist([blood_sugar_men,blood_sugar_women],bins=[80,100,125,150],rwidth=0.95,color=['r','g'],label=['men','women'])
plt.legend()

# %%
blood_sugar_men=[113,85,91,150,149,88,93,115,135,80,77,82,129]
blood_sugar_women=[120,98,87,145,134,143,120,99,142,67,100,149,150]

plt.xlabel("sugar range")
plt.ylabel("number of patients")
plt.title("blood sugar chart")
plt.hist([blood_sugar_men,blood_sugar_women],bins=[80,100,125,150],rwidth=0.95,color=['r','g'],label=['men','women'],orientation='horizontal')
plt.legend()
