# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use('seaborn')

# %%
x=[12,23,34,556,1,2,3,4,7,5,67,76,54,87]
y=[45,56,67,89,90,77,44,78,65,43,32,22,8,87]

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y,color='r')

# %%
plt.scatter(x,y,color='r',edgecolor='black',linewidth=1)

# %%
plt.scatter(x,y,color='r',edgecolor='black',linewidth=1)

plt.title('trending youtube videos')
plt.xlabel('view count')
plt.ylabel('total likes')

plt.tight_layout()
plt.show()
